# %% [markdown]
# ## Agglomerative-Clustering

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
datasets=pd.read_csv("football_data.csv")

# %%
datasets.head()
# Out:
#        Player Name    Position  Goals  Assists  Tackles  Pass Accuracy  \
# 0           Neymar  Midfielder     17       10      103          84.20
# 1           Neymar  Midfielder      3        8       52          96.36
# 2  Kevin De Bruyne    Defender     25       21       12          83.16
# 3  Kevin De Bruyne     Forward     23       13      118          97.83
# 4  Kevin De Bruyne  Midfielder     24        6       47          88.44
#
#    Dribbles per Game  Interceptions  Shots per Game  Yellow Cards  Red Cards
# 0               4.11              0            4.16             3          1
# 1               5.18             26            0.85             0          1
# 2               5.52              4            1.38             0          2
# 3               3.78             49            0.18             0          0
# 4               0.62              4            1.15             9          1

# %%
new_dataset=datasets[["Goals","Assists","Tackles","Pass Accuracy"]]

# %%
sns.pairplot(data=new_dataset)
plt.show()

# %%
from scipy.cluster import hierarchy as sc

# %%
sc=sc.dendrogram(sc.linkage(new_dataset ,method='single',metric="euclidean"))
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
ag=AgglomerativeClustering(n_clusters=4,linkage="single")
ag.fit_predict(new_dataset)
new_dataset["predicts"]=ag.fit_predict(new_dataset)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15308\2119891008.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_dataset["predicts"]=ag.fit_predict(new_dataset)

# %%
sns.pairplot(new_dataset,hue="predicts")
plt.show()
